# %%
import cv2
import numpy as np 
import os
from PIL import Image
import PIL
import math
import matplotlib.pyplot as plt
PIL.Image.MAX_IMAGE_PIXELS = 10000000000000

# %%
img=Image.open('../../data/not_transition/CODIPAI-THCB-SS-00011-S-CN-01.tiff')

# %%
max_size=4096
width=img.size[0]
height=img.size[1]
resize_width=0
resize_height=0
ratio=0
if width>height:
    ratio=4096/width
    resize_height=height*ratio
    resize_width=max_size
    resize_height=math.ceil(resize_height)
else:
    ratio=4096/height
    resize_height=max_size
    resize_width=width*ratio
    resize_width=math.ceil(resize_width)
img_resize=img.resize(([resize_width,resize_height]))

# %%
img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=4096x1318 at 0x7EF73A94F520>
